# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk import word_tokenize

# %%
pd.set_option('display.max_columns', None)

file = pd.read_csv(r'C:\Users\xuanx\Desktop\Steam_Reviews\steam_reviews.csv')
print(file)
# Out:
#           Unnamed: 0  app_id                  app_name  review_id  language  \
# 0                  0  292030  The Witcher 3: Wild Hunt   85185598  schinese
# 1                  1  292030  The Witcher 3: Wild Hunt   85185250  schinese
# 2                  2  292030  The Witcher 3: Wild Hunt   85185111  schinese
# 3                  3  292030  The Witcher 3: Wild Hunt   85184605   english
# 4                  4  292030  The Witcher 3: Wild Hunt   85184287  schinese
# ...              ...     ...                       ...        ...       ...
# 21747366    21747371  546560           Half-Life: Alyx   65645125   english
# 21747367    21747372  546560           Half-Life: Alyx   65645115   english
# 21747368    21747373  546560           Half-Life: Alyx   65645100   english
# 21747369    21747374  546560           Half-Life: Alyx   65645066   english
# 21747370    21747375  546560           Half-Life: Alyx   65644930  schinese
#
#                                                      review  \
# 0                                   不玩此生遗憾，RPG游戏里的天花板，太吸引人了
# 1                                        拔DIAO无情打桩机--杰洛特!!!
# 2                                                     巫师3NB
# 3         One of the best RPG's of all time, worthy of a...
# 4                                                        大作
# ...                                                     ...
# 21747366                                         Holy balls
# 21747367  A tripod thing bears down on you, it looks imm...
# 21747368             Honestly this is the best vr game ever
# 21747369  Smooth turning is not working right now.\nIt a...
# 21747370  WMR加载中闪退，无法进入游戏\nWMR Flashback in Load，cant pl...
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 0                1611381629         1611381629         True              0
# 1                1611381030         1611381030         True              0
# 2                1611380800         1611380800         True              0
# 3                1611379970         1611379970         True              0
# 4                1611379427         1611379427         True              0
# ...                     ...                ...          ...            ...
# 21747366         1584986704         1584986704         True              0
# 21747367         1584986693         1584986693         True              0
# 21747368         1584986673         1584986673         True              0
# 21747369         1584986631         1586382422         True              0
# 21747370         1584986505         1592060800         True              0
#
#           votes_funny  weighted_vote_score  comment_count  steam_purchase  \
# 0                   0             0.000000              0            True
# 1                   0             0.000000              0            True
# 2                   0             0.000000              0            True
# 3                   0             0.000000              0            True
# 4                   0             0.000000              0            True
# ...               ...                  ...            ...             ...
# 21747366            0             0.000000              0            True
# 21747367            0             0.000000              0           False
# 21747368            0             0.474138              0            True
# 21747369            0             0.386022             11            True
# 21747370            0             0.416107              5            True
#
#           received_for_free  written_during_early_access     author.steamid  \
# 0                     False                        False  76561199095369542
# 1                     False                        False  76561198949504115
# 2                     False                        False  76561199090098988
# 3                     False                        False  76561199054755373
# 4                     False                        False  76561199028326951
# ...                     ...                          ...                ...
# 21747366              False                        False  76561197967033932
# 21747367              False                        False  76561198046495482
# 21747368              False                        False  76561198176379749
# 21747369              False                        False  76561198041763187
# 21747370              False                        False  76561198116747069
#
#           author.num_games_owned  author.num_reviews  author.playtime_forever  \
# 0                              6                   2                   1909.0
# 1                             30                  10                   2764.0
# 2                              5                   1                   1061.0
# 3                              5                   3                   5587.0
# 4                              7                   4                    217.0
# ...                          ...                 ...                      ...
# 21747366                     431                   7                    432.0
# 21747367                      70                  10                   3296.0
# 21747368                      79                  17                   2654.0
# 21747369                     140                   3                    210.0
# 21747370                     253                   7                   1062.0
#
#           author.playtime_last_two_weeks  author.playtime_at_review  \
# 0                                 1448.0                     1909.0
# 1                                 2743.0                     2674.0
# 2                                 1061.0                     1060.0
# 3                                 3200.0                     5524.0
# 4                                   42.0                      217.0
# ...                                  ...                        ...
# 21747366                             0.0                       29.0
# 21747367                            15.0                       24.0
# 21747368                             0.0                       34.0
# 21747369                             0.0                       12.0
# 21747370                             0.0                        8.0
#
#           author.last_played
# 0               1.611343e+09
# 1               1.611386e+09
# 2               1.611384e+09
# 3               1.611384e+09
# 4               1.610788e+09
# ...                      ...
# 21747366        1.586628e+09
# 21747367        1.611080e+09
# 21747368        1.591634e+09
# 21747369        1.589715e+09
# 21747370        1.602858e+09
#
# [21747371 rows x 23 columns]

# %%
file['language'].value_counts()
# Out:
# english       9635437
# schinese      3764967
# russian       2348900
# brazilian      837524
# spanish        813320
# german         752596
# turkish        635868
# koreana        613632
# french         541751
# polish         495529
# tchinese       218203
# czech          133980
# italian        133307
# thai           127503
# japanese        81754
# portuguese      81386
# swedish         80226
# dutch           77555
# hungarian       71001
# latam           70103
# danish          55915
# finnish         54712
# norwegian       36797
# romanian        32730
# ukrainian       21169
# greek           14472
# bulgarian       10454
# vietnamese       6580
# Name: language, dtype: int64

# %%
#pick out english reviews only
df = file[file['language'] == 'english']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9635437 entries, 3 to 21747369
# Data columns (total 23 columns):
# Unnamed: 0                        int64
# app_id                            int64
# app_name                          object
# review_id                         int64
# language                          object
# review                            object
# timestamp_created                 int64
# timestamp_updated                 int64
# recommended                       bool
# votes_helpful                     int64
# votes_funny                       int64
# weighted_vote_score               float64
# comment_count                     int64
# steam_purchase                    bool
# received_for_free                 bool
# written_during_early_access       bool
# author.steamid                    int64
# author.num_games_owned            int64
# author.num_reviews                int64
# author.playtime_forever           float64
# author.playtime_last_two_weeks    float64
# author.playtime_at_review         float64
# author.last_played                float64
# dtypes: bool(4), float64(5), int64(11), object(3)
# memory usage: 1.5+ GB

# %%
df['recommended'].value_counts()
# Out:
# True     8584444
# False    1050993
# Name: recommended, dtype: int64

# %%
import warnings 

warnings.filterwarnings('ignore')

# %%
#Checking review column for null values and removing them.
df.review.isnull().sum()
df1 = df[df.review.isnull()== False]

# %%
games_list = df['app_name'].value_counts().to_frame()
games_list
# Out:
#                                        app_name
# Tom Clancy's Rainbow Six Siege           371154
# Terraria                                 370240
# Garry's Mod                              331621
# Grand Theft Auto V                       319751
# PLAYERUNKNOWN'S BATTLEGROUNDS            317846
# ...                                         ...
# DRAGON QUEST HEROES™ II                     348
# Senren＊Banka                                271
# Battle Royale Trainer                       228
# 三国群英传8 Heroes of the Three Kingdoms 8        65
# Neon Hardcorps                               61
#
# [315 rows x 1 columns]

# %%
print(games_list.index.to_frame())
# Out:
#                                                                            0
# Tom Clancy's Rainbow Six Siege                Tom Clancy's Rainbow Six Siege
# Terraria                                                            Terraria
# Garry's Mod                                                      Garry's Mod
# Grand Theft Auto V                                        Grand Theft Auto V
# PLAYERUNKNOWN'S BATTLEGROUNDS                  PLAYERUNKNOWN'S BATTLEGROUNDS
# ...                                                                      ...
# DRAGON QUEST HEROES™ II                              DRAGON QUEST HEROES™ II
# Senren＊Banka                                                    Senren＊Banka
# Battle Royale Trainer                                  Battle Royale Trainer
# 三国群英传8 Heroes of the Three Kingdoms 8  三国群英传8 Heroes of the Three Kingdoms 8
# Neon Hardcorps                                                Neon Hardcorps
#
# [315 rows x 1 columns]

# %%
games_list_20 = games_list.sample(frac=0.03, random_state = 40)
games_list_20.shape
# Out:
# (9, 1)

# %%
games_list_20_list = games_list_20.index.tolist()
df_20 = df.loc[(df['app_name'].isin(games_list_20_list))]

# %%
df_20.shape
# Out:
# (263815, 23)

# %%
df_20['app_name'].value_counts()
# Out:
# ARK: Survival Evolved           184576
# Deep Rock Galactic               47002
# Assassin's Creed Origins         17832
# Avorion                           5056
# FAR: Lone Sails                   3834
# Titan Souls                       2633
# Iconoclasts                       1492
# SENRAN KAGURA ESTIVAL VERSUS      1119
# Senren＊Banka                       271
# Name: app_name, dtype: int64

# %%
print(games_list_20_list)
# Out:
# ['Avorion', 'Senren＊Banka', 'Iconoclasts', 'FAR: Lone Sails', 'Deep Rock Galactic', 'Titan Souls', "Assassin's Creed Origins", 'SENRAN KAGURA ESTIVAL VERSUS', 'ARK: Survival Evolved']

# %%
df_20['recommended'].value_counts()
# Out:
# True     212055
# False     51760
# Name: recommended, dtype: int64

# %%
df_20.review = df_20.review.astype(str)

# %%
import string
import re

# %%
#Convert text to lowercase and removing punctuation 

def remove_punct(txt):
    text_input = "".join([char for char in txt if char not in string.punctuation])
    return text_input

df_20['token_review'] = df_20['review'].apply(lambda x: remove_punct(x.lower()))

# %%
#remove numbers

def remove_digits(txt):
    return re.sub(r' \d+', '', str(txt))

df_20['token_review1'] = df_20['token_review'].apply(lambda x: remove_digits(x))

# %%
#remove non alphabet characters

def remove_chars(txt):
    return re.sub("[^a-zA-Z]+", ' ', txt)

df_20['token_review2'] = df_20['token_review1'].apply(lambda x: remove_chars(x))

# %%
#Convert reviews into tokens

def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

df_20['token_review3'] = df_20['token_review2'].apply(lambda x: tokenize(x))

# %%
#remove stopwords

stopword = nltk.corpus.stopwords.words('english')

def rem_stopwords(txt):
    text = [word for word in txt if word not in stopword]
    return text

df_20['token_review4'] = df_20['token_review3'].apply(lambda x: rem_stopwords(x))

# %%
#convert words to base form 
wn = nltk.WordNetLemmatizer()

def lemmatizer(txt):
    text = [wn.lemmatize(word) for word in txt]
    return text

df_20['token_review5']=df_20['token_review4'].apply(lambda x: lemmatizer(x))

# %%
print(df_20)
# Out:
#           Unnamed: 0  app_id                      app_name  review_id  \
# 3479586      3479587  297130                   Titan Souls   84708301
# 3479589      3479590  297130                   Titan Souls   84656454
# 3479592      3479593  297130                   Titan Souls   84566885
# 3479597      3479598  297130                   Titan Souls   84529848
# 3479598      3479599  297130                   Titan Souls   84527167
# ...              ...     ...                           ...        ...
# 21633098    21633103  502800  SENRAN KAGURA ESTIVAL VERSUS   30575218
# 21633099    21633104  502800  SENRAN KAGURA ESTIVAL VERSUS   30574627
# 21633109    21633114  502800  SENRAN KAGURA ESTIVAL VERSUS   30573550
# 21633110    21633115  502800  SENRAN KAGURA ESTIVAL VERSUS   30573509
# 21633114    21633119  502800  SENRAN KAGURA ESTIVAL VERSUS   85191387
#
#          language                                             review  \
# 3479586   english  What an amazingly made game. I love the combat...
# 3479589   english  This game is dope! Its got the old school retr...
# 3479592   english   Good sprites and artwork, but pretty challenging
# 3479597   english  More walking than fighting.\nHard for the sake...
# 3479598   english                                           BIT SHIT
# ...           ...                                                ...
# 21633098  english  You can headpat the girls now. I repeat. YOU C...
# 21633099  english                               Is this battletoads?
# 21633109  english  This game is true love. If you like anime, you...
# 21633110  english                                   boobs everywhere
# 21633114  english                                              Y e s
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 3479586          1610685143         1610685143         True              0
# 3479589          1610608923         1610608923         True              0
# 3479592          1610476646         1610476646         True              0
# 3479597          1610423062         1610423062        False              1
# 3479598          1610418255         1610418255        False              0
# ...                     ...                ...          ...            ...
# 21633098         1489778761         1489781002         True             29
# 21633099         1489777051         1489777051         True              7
# 21633109         1489773835         1501566889         True              0
# 21633110         1489773684         1494695857         True              1
# 21633114         1611391378         1611391378         True              0
#
#           votes_funny  weighted_vote_score  comment_count  steam_purchase  \
# 3479586             0             0.000000              0            True
# 3479589             0             0.000000              0            True
# 3479592             0             0.000000              0            True
# 3479597             1             0.484234              0            True
# 3479598             0             0.390732              0           False
# ...               ...                  ...            ...             ...
# 21633098           36             0.614652             13            True
# 21633099           13             0.464248              0            True
# 21633109            0             0.000000              0            True
# 21633110            1             0.523810              1            True
# 21633114            0             0.000000              0           False
#
#           received_for_free  written_during_early_access     author.steamid  \
# 3479586               False                        False  76561198120568897
# 3479589               False                        False  76561198290996480
# 3479592               False                        False  76561199062747782
# 3479597               False                        False  76561198145707517
# 3479598               False                        False  76561198277120098
# ...                     ...                          ...                ...
# 21633098              False                        False  76561197992673878
# 21633099              False                        False  76561198034281622
# 21633109              False                        False  76561198131207799
# 21633110              False                        False  76561198107697880
# 21633114              False                        False  76561198162226762
#
#           author.num_games_owned  author.num_reviews  author.playtime_forever  \
# 3479586                       12                   3                    118.0
# 3479589                       50                   1                    287.0
# 3479592                       37                   3                     82.0
# 3479597                       13                   2                     93.0
# 3479598                      121                  53                     75.0
# ...                          ...                 ...                      ...
# 21633098                     917                  40                    242.0
# 21633099                      98                   6                  15370.0
# 21633109                     135                   8                   5100.0
# 21633110                     234                   9                   1313.0
# 21633114                      94                   1                   2269.0
#
#           author.playtime_last_two_weeks  author.playtime_at_review  \
# 3479586                            118.0                      118.0
# 3479589                            294.0                      111.0
# 3479592                             82.0                       66.0
# 3479597                             93.0                       93.0
# 3479598                             75.0                       75.0
# ...                                  ...                        ...
# 21633098                             0.0                      164.0
# 21633099                             0.0                      529.0
# 21633109                             0.0                     5100.0
# 21633110                             0.0                      426.0
# 21633114                             0.0                     2269.0
#
#           author.last_played  \
# 3479586         1.610685e+09
# 3479589         1.610653e+09
# 3479592         1.610757e+09
# 3479597         1.610423e+09
# 3479598         1.610418e+09
# ...                      ...
# 21633098        1.490586e+09
# 21633099        1.608740e+09
# 21633109        1.506219e+09
# 21633110        1.553649e+09
# 21633114        1.599976e+09
#
#                                                token_review  \
# 3479586   what an amazingly made game i love the combat ...
# 3479589   this game is dope its got the old school retro...
# 3479592     good sprites and artwork but pretty challenging
# 3479597   more walking than fighting\nhard for the sake ...
# 3479598                                            bit shit
# ...                                                     ...
# 21633098  you can headpat the girls now i repeat you can...
# 21633099                                is this battletoads
# 21633109  this game is true love if you like anime you w...
# 21633110                                   boobs everywhere
# 21633114                                              y e s
#
#                                               token_review1  \
# 3479586   what an amazingly made game i love the combat ...
# 3479589   this game is dope its got the old school retro...
# 3479592     good sprites and artwork but pretty challenging
# 3479597   more walking than fighting\nhard for the sake ...
# 3479598                                            bit shit
# ...                                                     ...
# 21633098  you can headpat the girls now i repeat you can...
# 21633099                                is this battletoads
# 21633109  this game is true love if you like anime you w...
# 21633110                                   boobs everywhere
# 21633114                                              y e s
#
#                                               token_review2  \
# 3479586   what an amazingly made game i love the combat ...
# 3479589   this game is dope its got the old school retro...
# 3479592     good sprites and artwork but pretty challenging
# 3479597   more walking than fighting hard for the sake o...
# 3479598                                            bit shit
# ...                                                     ...
# 21633098  you can headpat the girls now i repeat you can...
# 21633099                                is this battletoads
# 21633109  this game is true love if you like anime you w...
# 21633110                                   boobs everywhere
# 21633114                                              y e s
#
#                                               token_review3  \
# 3479586   [what, an, amazingly, made, game, i, love, the...
# 3479589   [this, game, is, dope, its, got, the, old, sch...
# 3479592   [good, sprites, and, artwork, but, pretty, cha...
# 3479597   [more, walking, than, fighting, hard, for, the...
# 3479598                                         [bit, shit]
# ...                                                     ...
# 21633098  [you, can, headpat, the, girls, now, i, repeat...
# 21633099                            [is, this, battletoads]
# 21633109  [this, game, is, true, love, if, you, like, an...
# 21633110                                [boobs, everywhere]
# 21633114                                          [y, e, s]
#
#                                               token_review4  \
# 3479586   [amazingly, made, game, love, combat, music, a...
# 3479589   [game, dope, got, old, school, retro, look, on...
# 3479592       [good, sprites, artwork, pretty, challenging]
# 3479597   [walking, fighting, hard, sake, hard, without,...
# 3479598                                         [bit, shit]
# ...                                                     ...
# 21633098  [headpat, girls, repeat, headpat, girls, kunoi...
# 21633099                                      [battletoads]
# 21633109  [game, true, love, like, anime, wont, go, wron...
# 21633110                                [boobs, everywhere]
# 21633114                                                [e]
#
#                                               token_review5
# 3479586   [amazingly, made, game, love, combat, music, a...
# 3479589   [game, dope, got, old, school, retro, look, on...
# 3479592        [good, sprite, artwork, pretty, challenging]
# 3479597   [walking, fighting, hard, sake, hard, without,...
# 3479598                                         [bit, shit]
# ...                                                     ...
# 21633098  [headpat, girl, repeat, headpat, girl, kunoich...
# 21633099                                      [battletoads]
# 21633109  [game, true, love, like, anime, wont, go, wron...
# 21633110                                 [boob, everywhere]
# 21633114                                                [e]
#
# [263815 rows x 29 columns]

# %%
df_20['reviews_fin'] = df_20['token_review5'].apply(lambda x:' '.join(x))
df_20['rec_var'] = df_20['recommended'].apply(lambda x: 0 if x==1 else 1)

# %%
pos_reviews = df_20[df_20['recommended']== 0] #majority variable positive reviews
neg_reviews = df_20[df_20['recommended']== 1] #minority variable negative reviews

# %%
pos_reviews['review'].count()
neg_reviews['review'].count()
# Out:
# 212055

# %%
from nltk.probability import FreqDist

pos_rev_words = pos_reviews['token_review5']
pos_words = []
for reviews in pos_rev_words: 
    pos_words += reviews
    
freqdist_pos = FreqDist(pos_words)

# %%
neg_rev_words = neg_reviews['token_review5']
neg_words = []
for reviews in neg_rev_words: 
    neg_words += reviews
    
freqdist_neg = FreqDist(neg_words)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 800,
                     background_color = 'white',
                     stopwords = stopword,
                     min_font_size = 10).generate_from_frequencies(freqdist_pos)

plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
wordcloud = WordCloud(width = 800, height = 800,
                     background_color = 'white',
                     stopwords = stopword,
                     min_font_size = 10).generate_from_frequencies(freqdist_neg)

plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
(pd.Series(nltk.ngrams(pos_words, 2)).value_counts())[:10]
# Out:
# (early, access)       7549
# (play, game)          3193
# (paid, dlc)           2944
# (buy, game)           2487
# (recommend, game)     2253
# (game, still)         2168
# (official, server)    2160
# (access, game)        1952
# (dont, buy)           1910
# (survival, game)      1705
# dtype: int64

# %%
(pd.Series(nltk.ngrams(pos_words, 3)).value_counts())[:10]
# Out:
# (early, access, game)       1913
# (dlc, early, access)        1056
# (evil, evil, evil)           862
# (still, early, access)       804
# (game, early, access)        736
# (dont, buy, game)            690
# (paid, dlc, early)           653
# (ark, survival, evolved)     509
# (paid, dlc, game)            463
# (fix, fix, fix)              444
# dtype: int64

# %%
(pd.Series(nltk.ngrams(neg_words, 2)).value_counts())[:10]
# Out:
# (great, game)       14555
# (good, game)        12896
# (early, access)      9283
# (survival, game)     9265
# (rock, stone)        9241
# (fun, game)          8541
# (love, game)         7591
# (best, game)         6836
# (game, play)         6656
# (game, ever)         5366
# dtype: int64

# %%
(pd.Series(nltk.ngrams(neg_words, 3)).value_counts())[:10]
# Out:
# (best, game, ever)          2730
# (early, access, game)       2635
# (rock, stone, rock)         2163
# (stone, rock, stone)        2140
# (one, best, game)           2022
# (fun, fun, fun)             1918
# (game, play, friend)        1740
# (ark, survival, evolved)    1734
# (game, ever, played)        1728
# (deep, rock, galactic)      1723
# dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
df_x = df_20['reviews_fin']
y = df_20['rec_var']
X_train, X_test, y_train, y_test = train_test_split(df_x, y, 
                                                    test_size = 0.2, random_state = 42)

# %%
vectorizer = TfidfVectorizer()
train_features = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_features.shape, test_vectors.shape)
# Out:
# (211052, 117913) (52763, 117913)

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline
from time import time
from pprint import pprint
import logging
from sklearn.metrics import recall_score, roc_auc_score, make_scorer, roc_curve

# %%
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier

cv = KFold(n_splits=5)


pipe_multi = Pipeline([('vect', TfidfVectorizer()),
                      ('clf', MultinomialNB())])

pipe_rf = Pipeline([('vect', TfidfVectorizer()),
                      ('clf', RandomForestClassifier(random_state = 42))])


grid_params_multi = {'vect__ngram_range': [(1,1), (2,2), (3,3)]
                     }

grid_params_rf = {'vect__ngram_range': [(1,1), (2,2), (3,3)],
                  'clf__max_depth': [10, 20, 50, 100],
                  'clf__n_estimators': [200, 400, 600, 800]
                     }

multiNB = GridSearchCV(estimator = pipe_multi,
                      param_grid = grid_params_multi,
                      scoring = 'roc_auc',
                      cv = cv, 
                       n_jobs = -1)

rf = GridSearchCV(estimator = pipe_rf,
                  param_grid = grid_params_rf,
                  scoring = 'roc_auc',
                  cv = cv, 
                  n_jobs = -1)

grids = [multiNB, rf] #rf

grid_dict = {0: 'Naive Bayes',
            1: 'Random Forest'}

print('Performing Model Optimizations')
best_auc = 0.0
best_clf = 0
best_gs = ''

for idx, gs in enumerate(grids):
    print('\nEstimator: %s' % grid_dict[idx])
    gs.fit(X_train, y_train)
    print('Best params are : %s' % gs.best_params_)
    # Best training data recall score
    print('Best training AUC score: %.3f' % gs.best_score_)
    # Predict on test data with best params
    y_pred_proba = gs.predict_proba(X_test)[:,1]
    # Test data accuracy of model with best params
    print('Test set AUC score for best params: %.3f ' % roc_auc_score(y_test, y_pred_proba))
    #Plot ROC curve for each estimator
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    auc = roc_auc_score(y_test,y_pred_proba)
    plt.plot([0,1],[0,1], linestyle ='--')
    plt.plot(fpr, tpr, label = 'auc=%.3f' % auc)
    plt.title(label = 'ROC Curve %s' % grid_dict[idx])
    plt.show()
    # Track best (highest test auc) model
    if roc_auc_score(y_test, y_pred_proba) > best_auc:
        best_auc = roc_auc_score(y_test, y_pred_proba)
        best_gs = gs
        best_clf = idx
print('\nClassifier with best test set AUC: %s' % grid_dict[best_clf])
# Out:
# Performing Model Optimizations
#
# Estimator: Naive Bayes
# Best params are : {'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.906
# Test set AUC score for best params: 0.908
# Estimator: Random Forest
# Best params are : {'clf__max_depth': 100, 'clf__n_estimators': 800, 'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.911
# Test set AUC score for best params: 0.911
# Classifier with best test set AUC: Random Forest

# %%
print(rf.best_params_)
# Out:
# {'clf__max_depth': 100, 'clf__n_estimators': 800, 'vect__ngram_range': (1, 1)}

# %%
clf_rf = Pipeline([('vect', TfidfVectorizer(ngram_range = (1,1))),
                   ('clf', RandomForestClassifier(random_state = 42, 
                                                  max_depth= 100, n_estimators= 800))])
clf_fit = clf_rf.fit(X_train, y_train)

# %%
from scipy import interpolate
from sklearn import metrics

y_pred_proba = clf_fit.predict_proba(X_test)[:,1]

# %%
y_test.value_counts()
# Out:
# 0    42385
# 1    10378
# Name: rec_var, dtype: int64

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold = %f, F-Score = %.3f' % (thresholds[ix], fscore[ix]))
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(recall[ix], precision[ix], marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.show()
optimal_thresh = thresholds[ix]
optimal_prec = precision[ix]
# Out:
# Best Threshold = 0.279933, F-Score = 0.686

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# %%
precision.shape, recall.shape, thresholds.shape
# Out:
# ((40450,), (40450,), (40449,))

# %%
precision = np.delete(precision, -1)
recall = np.delete(recall, -1)

precision.shape, recall.shape, thresholds.shape
# Out:
# ((40449,), (40449,), (40449,))

# %%
#locate recall from selected precision

precision_score = optimal_prec
find_recall = interpolate.interp1d(precision, recall)
find_thresh = interpolate.interp1d(precision, thresholds)
thresh_value = find_thresh(precision_score)
recall_score = find_recall(precision_score)
recall_score, thresh_value
# Out:
# (array(0.70167662), array(0.27993289))

# %%
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(recall_score, prec_score, marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1a6fbda669f0> in <module>
#       1 plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
# ----> 2 plt.plot(recall_score, prec_score, marker = 'o', color = 'black', label = 'Best')
#       3 plt.title(label = 'Precision Recall Curve')
#       4 plt.show()
#
# NameError: name 'prec_score' is not defined

# %%
from sklearn.metrics import confusion_matrix

y_pred = (y_pred_proba > 0.5)
conf_mat = confusion_matrix(y_test, y_pred, labels = [1,0])
conf_mat

# %% [markdown]
# ## Unused Code For Now

# %%
tpr_opt = find_tpr(thresh_value)
fpr_opt = find_fpr(thresh_value)
print(tpr_opt, fpr_opt, thresh_value)

# %%
#locating optimal point
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

find_tpr = interpolate.interp1d(thresholds, tpr) #plug in thresholds for tpr
find_fpr = interpolate.interp1d(thresholds, fpr) #plug in thresh for fpr
thresh_look = interpolate.interp1d(tpr, thresholds) #plug in tpr for thresholds

# %%
ttt = thresh_look(0.6) #threshold value for value of tpr
ttt

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
auc = roc_auc_score(y_test,y_pred_proba)
plt.plot([0,1],[0,1], linestyle ='--')
plt.plot(fpr, tpr, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(fpr_opt, tpr_opt, marker = 'o', color = 'black')
plt.title(label = 'ROC Curve Random Forest Classifier')
plt.show()

# %%
y_pred_opt = (y_pred_proba > ttt)
conf_mat_opt = confusion_matrix(y_test, y_pred_opt, labels = [0,1])
conf_mat_opt

# %%
#find best true negative (tn) results
tn = 7000
best_thresh = 0
for t in high_thresh:
    y_pred_opt = (y_pred_proba > t)
    conf_mat_opt = confusion_matrix(y_test, y_pred_opt, labels = [0,1])
    if conf_mat_opt[1][0] > tn:
        best_thresh = t
        tn = conf_mat_opt[1][0]
        conf_mat_best = conf_mat_opt

best_thresh, tn, conf_mat_best

# %%
high_thresh = thresholds[thresholds > 0.5]
high_thresh

# %%
from sklearn.metrics import accuracy_score

#accuracy prior to choosing threshold
accuracy = accuracy_score(y_test, y_pred_proba.astype('int'))
print(accuracy)

# %%
y_pred = y_pred_proba
y_pred = (y_pred >= opt_thresh).astype('int')

accuracy_thresh = accuracy_score(y_test, y_pred)
print(accuracy_thresh)

# %%
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(0.9, prec_point, marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.show()
