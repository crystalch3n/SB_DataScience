# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore', category = DeprecationWarning)
import nltk
from nltk import word_tokenize
from datetime import datetime
import scipy.stats.distributions as dist

from statsmodels.stats.proportion import proportions_ztest


from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
import datetime
import tensorflow as tf
import tensorflow.keras

import string
import re

# %%
pd.set_option('display.max_columns', None)

file = pd.read_csv(r'C:\Users\xuanx\Capstone 2 Pollution\archive\steam_reviews.csv')

# %%
file['language'].value_counts()[:5]
# Out:
# language
# english      9635437
# schinese     3764967
# russian      2348900
# brazilian     837524
# spanish       813320
# Name: count, dtype: int64

# %%
#separate out english reviews only
df_eng = file[file['language'] == 'english']

# %%
df_eng['app_name'].value_counts()[:5]
# Out:
# app_name
# Tom Clancy's Rainbow Six Siege    371154
# Terraria                          370240
# Garry's Mod                       331621
# Grand Theft Auto V                319751
# PLAYERUNKNOWN'S BATTLEGROUNDS     317846
# Name: count, dtype: int64

# %%
#subtract terraria for SHAP evaluation at end
df_ter = df_eng[df_eng['app_name'] == "Terraria"]
df = df_eng[df_eng['app_name'] != "Terraria"]

# %%
#Checking review column for null values and removing them.
print(df.review.isnull().sum())
df1 = df[df.review.isnull()== False]
# Out:
# 16139

# %%
df1['recommended'].value_counts()
# Out:
# recommended
# True     8205745
# False    1043313
# Name: count, dtype: int64

# %%
#Hypothesis testing: early access population mean versus release reviews means
df1.groupby('written_during_early_access')['recommended'].value_counts()
# Out:
# written_during_early_access  recommended
# False                        True           7378159
#                              False           912562
# True                         True            827586
#                              False           130751
# Name: count, dtype: int64

# %%
prop = df1.groupby('written_during_early_access')['recommended'].value_counts(normalize = True)
prop
# Out:
# written_during_early_access  recommended
# False                        True           0.889930
#                              False          0.110070
# True                         True           0.863565
#                              False          0.136435
# Name: proportion, dtype: float64

# %%
n = df1.groupby('written_during_early_access')['recommended'].count()
n
# Out:
# written_during_early_access
# False    8290721
# True      958337
# Name: recommended, dtype: int64

# %%
prop_early = prop[(True, False)]
prop_not_early = prop[(False, False)]
print(prop_early, prop_not_early)
# Out:
# 0.1364353040736192 0.1100702821865553

# %%
n_early = n[True]
n_not_early = n[False]
print(n_early, n_not_early)
# Out:
# 958337 8290721

# %%
p_hat = (n_early * prop_early + n_not_early * prop_not_early) / (n_early + n_not_early)
std_error = np.sqrt(p_hat * (1-p_hat) / n_early + p_hat * (1-p_hat) / n_not_early)
z_score = (prop_early - prop_not_early) / std_error
print(z_score)
# Out:
# 77.24419437518677

# %%
n_not_recommended = np.array([2644, 2597])
n_row = np.array([14424 + 2644, 6717 + 2597])
from statsmodels.stats.proportion import proportions_ztest
z_score, p_value = proportions_ztest(count = n_not_recommended, nobs = n_row, alternative = 'two-sided')
z_score, p_value

#Reject null hypothesis.
#There is a difference in proportion between not recommended reviews in early access and not recommended reviews outside
# of early access at a 1% level of significance.
# Out:
# (-24.108885753632578, 2.0170192587670853e-128)

# %%
#received for free population reviews versus paid population reviews

df1.groupby('received_for_free')['recommended'].value_counts()
# Out:
# received_for_free  recommended
# False              True           7967024
#                    False          1012645
# True               True            238721
#                    False            30668
# Name: count, dtype: int64

# %%
#received for free population = to paid population reviews?
rec_free_key = np.array([248307, 30925])
n_row = np.array([248307+30925, 8319820+1019635])

z_score, p_value = proportions_ztest(count = n_not_recommended, nobs = n_row, alternative = 'larger')
z_score, p_value
# Out:
# (205.07187963516282, 0.0)

# %%
#balance data set
df_clean = df1
df_20_20_samp = df_clean.groupby(['recommended'])
df_20_20_samp.size()
df_20_20 = df_20_20_samp.apply(lambda x: x.sample(100, replace = False, random_state = 42).reset_index(drop=True))
df_20_20['recommended'].value_counts()
#6000
# Out:
# recommended
# False    100
# True     100
# Name: count, dtype: int64

# %%
df_20_20 = df_20_20.droplevel(['recommended'])

# %%
df_20_20.review = df_20_20.review.astype(str)

# %%
#Convert text to lowercase and removing punctuation 

def remove_punct(txt):
    text_input = "".join([char for char in txt if char not in string.punctuation])
    return text_input

df_20_20['token_review'] = df_20_20['review'].apply(lambda x: remove_punct(x.lower()))

# %%
#remove numbers

def remove_digits(txt):
    return re.sub(r' \d+', '', str(txt))

df_20_20['token_review1'] = df_20_20['token_review'].apply(lambda x: remove_digits(x))

# %%
#remove non alphabet characters

def remove_chars(txt):
    return re.sub("[^a-zA-Z]+", ' ', txt)

df_20_20['token_review2'] = df_20_20['token_review1'].apply(lambda x: remove_chars(x))

# %%
#Convert reviews into tokens

def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

df_20_20['token_review3'] = df_20_20['token_review2'].apply(lambda x: tokenize(x))

# %%
#remove stopwords

stopword = nltk.corpus.stopwords.words('english')

def rem_stopwords(txt):
    text = [word for word in txt if word not in stopword]
    return text

df_20_20['token_review4'] = df_20_20['token_review3'].apply(lambda x: rem_stopwords(x))

# %%
#convert words to base form 
wn = nltk.WordNetLemmatizer()

def lemmatizer(txt):
    text = [wn.lemmatize(word) for word in txt]
    return text

df_20_20['token_review5']=df_20_20['token_review4'].apply(lambda x: lemmatizer(x))

# %%
df_20_20['reviews_fin'] = df_20_20['token_review5'].apply(lambda x:' '.join(x))
#df_20_20['rec_var'] = df_20_20['recommended'].apply(lambda x: 0 if x==1 else 1)

# %%
print(df_20_20.reviews_fin.isnull().sum())
# Out:
# 0

# %%
pos_reviews = df_20_20[df_20_20['recommended']== 1] #majority: variable positive reviews
neg_reviews = df_20_20[df_20_20['recommended']== 0] #minority: variable negative reviews

# %%
print(pos_reviews['review'].count(),
    neg_reviews['review'].count())
# Out:
# 100 100

# %%
from nltk.probability import FreqDist

pos_rev_words = pos_reviews['token_review5']
pos_words = []
for reviews in pos_rev_words: 
    pos_words += reviews
    
freqdist_pos = FreqDist(pos_words)
freqdist_pos
# Out:
# FreqDist({'game': 71, 'kid': 51, 'litthese': 38, 'good': 21, 'like': 15, 'great': 13, '': 13, 'lit': 12, 'really': 11, 'fun': 9, ...})

# %%
neg_rev_words = neg_reviews['token_review5']
neg_words = []
for reviews in neg_rev_words: 
    neg_words += reviews
    
freqdist_neg = FreqDist(neg_words)
freqdist_neg
# Out:
# FreqDist({'game': 184, 'play': 39, 'fun': 32, 'hour': 32, 'get': 31, 'time': 28, 'like': 26, 'one': 26, 'dont': 25, 'good': 19, ...})

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 800,
                     background_color = 'white',
                     stopwords = stopword,
                     min_font_size = 10).generate_from_frequencies(freqdist_pos)

plt.figure(figsize = (10,10), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('postive.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wordcloud = WordCloud(width = 800, height = 800,
                     background_color = 'white',
                     stopwords = stopword,
                     min_font_size = 10).generate_from_frequencies(freqdist_neg)

plt.figure(figsize = (10,10), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('negative.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
(pd.Series(nltk.ngrams(pos_words, 2)).value_counts())[:10]
# Out:
# (litthese, kid)    38
# (kid, litthese)    38
# (kid, lit)         12
# (lit, kid)         11
# (good, game)        5
# (great, game)       5
# (, game)            3
# (good, )            3
# (best, game)        3
# (game, )            3
# Name: count, dtype: int64

# %%
(pd.Series(nltk.ngrams(pos_words, 3)).value_counts())[:10]
# Out:
# (kid, litthese, kid)         38
# (litthese, kid, litthese)    37
# (kid, lit, kid)              11
# (lit, kid, lit)              10
# (worth, current, price)       1
# (current, price, ever)        1
# (price, ever, go)             1
# (ever, go, special)           1
# (go, special, buy)            1
# (someone, riding, horse)      1
# Name: count, dtype: int64

# %%
(pd.Series(nltk.ngrams(neg_words, 2)).value_counts())[:10]
# Out:
# (play, game)       8
# (dark, soul)       5
# (dont, buy)        5
# (buy, game)        5
# (feel, like)       4
# (hundred, hour)    4
# (game, fun)        4
# (bought, game)     4
# (time, game)       4
# (game, play)       4
# Name: count, dtype: int64

# %%
(pd.Series(nltk.ngrams(neg_words, 3)).value_counts())[:10]
# Out:
# (hundred, hour, planning)    2
# (game, im, enjoying)         2
# (game, year, ago)            2
# (blow, player, house)        2
# (game, pretty, fun)          2
# (gave, tonne, space)         2
# (may, seem, like)            2
# (worst, part, game)          2
# (take, way, much)            2
# (dont, buy, game)            2
# Name: count, dtype: int64

# %%
#run analysis on terraria data, tokenize terraria reviews
df_ter.review = df_ter.review.astype(str)
df_ter = df_ter.groupby(['recommended'])
df_tersamp = df_ter.apply(lambda x: x.sample(20, replace = False, random_state = 42).reset_index(drop=True))


#Convert text to lowercase and removing punctuation 
df_tersamp['token_review'] = df_tersamp['review'].apply(lambda x: remove_punct(x.lower()))

#remove numbers
df_tersamp['token_review1'] = df_tersamp['token_review'].apply(lambda x: remove_digits(x))

#remove non alphabet characters
df_tersamp['token_review2'] = df_tersamp['token_review1'].apply(lambda x: remove_chars(x))

#Convert reviews into tokens
df_tersamp['token_review3'] = df_tersamp['token_review2'].apply(lambda x: tokenize(x))

#remove stopwords
df_tersamp['token_review4'] = df_tersamp['token_review3'].apply(lambda x: rem_stopwords(x))

#convert words to base form 
df_tersamp['token_review5']=df_tersamp['token_review4'].apply(lambda x: lemmatizer(x))

df_tersamp['reviews_fin'] = df_tersamp['token_review5'].apply(lambda x:' '.join(x))
test = df_tersamp

test['recommended'].value_counts()
# Out:
# recommended
# False    20
# True     20
# Name: count, dtype: int64

# %%
train = df_20_20
train['recommended'].value_counts()
# Out:
# recommended
# False    100
# True     100
# Name: count, dtype: int64

# %%
X_train = train["reviews_fin"]
y_train = train['recommended'].replace({True: 1, False: 0})
X_test = test['reviews_fin']
y_test = test['recommended'].replace({True: 1, False: 0})

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
import xgboost

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline
from time import time
from pprint import pprint
import logging
from sklearn.metrics import recall_score, roc_auc_score, make_scorer, roc_curve
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
cv = KFold(n_splits=5, shuffle = True)


pipe_multi_count = Pipeline([('vect', CountVectorizer()),
                      ('clf', MultinomialNB())])

pipe_rf_count = Pipeline([('vect', CountVectorizer()),
                      ('clf', RandomForestClassifier(random_state = 42))])

pipe_multi_tfidf = Pipeline([('vect', TfidfVectorizer()),
                      ('clf', MultinomialNB())])

pipe_rf_tfidf = Pipeline([('vect', TfidfVectorizer()),
                      ('clf', RandomForestClassifier(random_state = 42))])


grid_params_multi = {'vect__ngram_range': [(1,1), (2,2), (3,3)]
                     }

grid_params_rf = {'vect__ngram_range': [(1,1), (2,2), (3,3)],
                  'clf__max_depth': [5, 10, None],
                  'clf__n_estimators': [200, 500, 800, 1000],
                  'clf__min_samples_leaf': [1, 50, 100]
                     }

multiNB = GridSearchCV(estimator = pipe_multi_count,
                       param_grid = grid_params_multi,
                       scoring = 'roc_auc',
                       cv = cv,
                       
                       error_score = 'raise',
                       n_jobs = -1)

rf = GridSearchCV(estimator = pipe_rf_count,
                  param_grid = grid_params_rf,
                  scoring = 'roc_auc',
                  cv = cv,
                  error_score = 'raise',
                  n_jobs = -1)

multiNB_tfidf = GridSearchCV(estimator = pipe_multi_tfidf,
                       param_grid = grid_params_multi,
                       scoring = 'roc_auc',
                       cv = cv,
                       
                       error_score = 'raise',
                       n_jobs = -1)

rf_tfidf = GridSearchCV(estimator = pipe_rf_tfidf,
                  param_grid = grid_params_rf,
                  scoring = 'roc_auc',
                  cv = cv,
                  error_score = 'raise',
                  n_jobs = -1)


grids = [multiNB, rf, multiNB_tfidf, rf_tfidf]

grid_dict = {0: 'NB countvects',
             1: 'rf countvects',
             2: "NB tfidf",
             3: 'rf tfidf'}

print('Performing Model Optimizations')
best_auc = 0.0
best_clf = 0
best_gs = ''

for idx, gs in enumerate(grids):
    print('\nEstimator: %s' % grid_dict[idx])
    gs.fit(X_train, y_train)
    print('Best params are : %s' % gs.best_params_)
    # Best training data recall score
    print('Best training AUC score: %.3f' % gs.best_score_)
    # Predict on test data with best params
    y_pred_proba = gs.predict_proba(X_test)[:,1]
    # Test data accuracy of model with best params
    print('Test set AUC score for best params: %.3f ' % roc_auc_score(y_test, y_pred_proba))
    #Plot ROC curve for each estimator
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    auc = roc_auc_score(y_test,y_pred_proba)
    plt.plot([0,1],[0,1], linestyle ='--')
    plt.plot(fpr, tpr, label = 'auc=%.3f' % auc)
    plt.title(label = 'ROC Curve %s' % grid_dict[idx])
    name = grid_dict[idx]
    plt.savefig(name + ".png")
    plt.show()
    # Track best (highest test auc) model
    if roc_auc_score(y_test, y_pred_proba) > best_auc:
        best_auc = roc_auc_score(y_test, y_pred_proba)
        best_gs = gs
        best_clf = idx
print('\nClassifier with best test set AUC: %s' % grid_dict[best_clf])
# Out:
# Performing Model Optimizations
#
# Estimator: NB countvects
# Best params are : {'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.746
# Test set AUC score for best params: 0.685
# Estimator: rf countvects
# Best params are : {'clf__max_depth': 5, 'clf__min_samples_leaf': 1, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.763
# Test set AUC score for best params: 0.750
# Estimator: NB tfidf
# Best params are : {'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.750
# Test set AUC score for best params: 0.755
# Estimator: rf tfidf
# Best params are : {'clf__max_depth': 10, 'clf__min_samples_leaf': 1, 'clf__n_estimators': 800, 'vect__ngram_range': (1, 1)}
# Best training AUC score: 0.787
# Test set AUC score for best params: 0.790
# Classifier with best test set AUC: rf tfidf

# %%
#setup clf for 
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_train_vec_df = pd.DataFrame(X_train_vec.toarray())
X_train_arr = X_train_vec.toarray()

X_test_vec = vectorizer.transform(X_test)
X_test_vec_df = pd.DataFrame(X_test_vec.toarray())
X_test_arr = X_test_vec.toarray()
X_test_vec_df.shape, X_train_vec_df.shape
# Out:
# ((40, 1913), (200, 1913))

# %%
words = vectorizer.get_feature_names_out()

# %%
X_train_vec_df.columns = words
X_test_vec_df.columns = words

# %%
n_words = X_train_arr.shape[1]

# %%
clf = RandomForestClassifier(random_state = 42, max_depth = 10, min_samples_leaf = 1, n_estimators = 1000)
clf_fit = clf.fit(X_train_arr, y_train)
y_pred_proba = clf.predict_proba(X_test_vec)[:,1]
auc = roc_auc_score(y_test, y_pred_proba)
auc
# Out:
# 0.7949999999999999

# %%
print(clf_fit)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=1000, random_state=42)

# %%
import shap
from scipy import interpolate
from sklearn import metrics

# %%
np.shape(X_test_vec_df)
# Out:
# (40, 1913)

# %%
feature_names = vectorizer.get_feature_names_out()

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
explainer = shap.TreeExplainer(clf_fit, X_train_vec_df, feature_names = vectorizer.get_feature_names_out())
shap_values = explainer.shap_values(X_test_vec_df)
shap_obj = explainer(X_test_vec_df)

# %%
type(shap_values)
# Out:
# numpy.ndarray

# %%
print(shap_obj.shape)
# Out:
# (40, 1913, 2)

# %%
shap.text_plot(shap_obj)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 shap.text_plot(shap_obj)
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_text.py:253, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#     246         for i, v in enumerate(shap_values):
#     247             out += f"""
#     248 <br>
#     249 <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     250 <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[{i}]</div>
#     251 </div>
#     252             """
# --> 253             out += text(
#     254                 v, num_starting_labels=num_starting_labels, grouping_threshold=grouping_threshold,
#     255                 separator=separator, xmin=xmin, xmax=xmax, cmax=cmax, display=False
#     256             )
#     257         if display:
#     258             _ipython_display_html(out)
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_text.py:200, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#     198 for i,name in enumerate(shap_values.output_names):
#     199     out += f"<div id='_tp_{uuid}_output_{i}' style='display: {'block' if i == 0 else 'none'}';>"
# --> 200     out += text(
#     201         shap_values[:, i], num_starting_labels=num_starting_labels, grouping_threshold=grouping_threshold,
#     202         separator=separator, xmin=xmin, xmax=xmax, cmax=cmax, display=False
#     203     )
#     204     out += "</div>"
#     205     out += f"<div id='_tp_{uuid}_output_{i}_zoom' style='display: none;'>"
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_text.py:285, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#     279 out = ""
#     280 # ev_str = str(shap_values.base_values)
#     281 # vsum_str = str(values.sum())
#     282 # fx_str = str(shap_values.base_values + values.sum())
#     283
#     284 #uuid = ''.join(random.choices(string.ascii_lowercase, k=20))
# --> 285 encoded_tokens = [t.replace("<", "&lt;").replace(">", "&gt;").replace(' ##', '') for t in tokens]
#     286 output_name = shap_values.output_names if isinstance(shap_values.output_names, str) else ""
#     287 out += svg_force_plot(values, shap_values.base_values, shap_values.base_values + values.sum(), encoded_tokens, uuid, xmin, xmax, output_name)
#
# AttributeError: 'numpy.float64' object has no attribute 'replace'

# %%
import copy

shap.initjs()
#shap_values1 = copy.deepcopy(shap_values)
#shap_values1.values = shap_values1.values[:,:,1]
#shap_values1.base_values = shap_values1.base_values[:,1]

shap.plots.beeswarm(shap_obj[:,:,0], max_display = 20, show= False)
plt.savefig('beeswarm.png', bbox_inches="tight")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
shap.summary_plot(shap_values[:,:,1], X_test_vec_df)

# %%
shap.plots.force(shap_values[ind,:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 shap.plots.force(shap_values[ind,:,1])
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_force.py:129, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     122     if not isinstance(shap_values, (list, np.ndarray)) or len(shap_values) != len(base_value):
#     123         emsg = (
#     124             "In v0.20, force plot now requires the base value as the first parameter! "
#     125             "Try shap.plots.force(explainer.expected_value, shap_values) or "
#     126             "for multi-output models try "
#     127             "shap.plots.force(explainer.expected_value[0], shap_values[..., 0])."
#     128         )
# --> 129         raise TypeError(emsg)
#     131 if isinstance(shap_values, list):
#     132     emsg = "The shap_values arg looks multi output, try `shap_values[i]` instead."
#
# TypeError: In v0.20, force plot now requires the base value as the first parameter! Try shap.plots.force(explainer.expected_value, shap_values) or for multi-output models try shap.plots.force(explainer.expected_value[0], shap_values[..., 0]).

# %%
shap.initjs()

ind = 10
print(X_test.iloc[ind], y_test.iloc[ind])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# buggy anything else single player great want play friend instruction get server running anything join server give exe run server doesnt anything even correct ip address wont sync player wasted p 0

# %%
shap.initjs()
example_shap_values = explainer.shap_values(X_test_vec_df.iloc[ind])
print(example_shap_values.shape)
shap.text_plot(example_shap_values)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# (1913, 2)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 4
#       2 example_shap_values = explainer.shap_values(X_test_vec_df.iloc[ind])
#       3 print(example_shap_values.shape)
# ----> 4 shap.text_plot(example_shap_values)
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_text.py:81, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#      78 uuid = ''.join(random.choices(string.ascii_lowercase, k=20))
#      80 # loop when we get multi-row inputs
# ---> 81 if len(shap_values.shape) == 2 and (shap_values.output_names is None or isinstance(shap_values.output_names, str)):
#      82     xmin = 0
#      83     xmax = 0
#
# AttributeError: 'numpy.ndarray' object has no attribute 'output_names'

# %%
shap.force_plot(explainer.expected_value, shap_values[0][ind,:], X_test_vec_df.iloc[ind,:], matplotlib=True, show=False)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 shap.force_plot(explainer.expected_value, shap_values[0][ind,:],X_test_vec_df.iloc[ind,:], matplotlib=True, show=False)
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_force.py:181, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     176     if len(features) == shap_values.shape[1] - 1:
#     177         emsg += (
#     178             " You might be using an old format shap_values array with the base value "
#     179             "as the last column. In this case, just pass the array without the last column."
#     180         )
# --> 181     raise DimensionError(emsg)
#     183 instance = Instance(np.zeros((1, len(feature_names))), features)
#     184 e = AdditiveExplanation(
#     185     base_value,
#     186     np.sum(shap_values[0, :]) + base_value,
#    (...)
#     192     DenseData(np.zeros((1, len(feature_names))), list(feature_names))
#     193 )
#
# DimensionError: Length of features is not equal to the length of shap_values!

# %%
shap.plots.waterfall(shap_values[ind,:,1])
plt.savefig('waterfall.png', bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 shap.plots.waterfall(shap_values[ind,:,1])
#       2 plt.savefig('waterfall.png', bbox_inches="tight")
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_waterfall.py:56, in waterfall(shap_values, max_display, show)
#      51 if not isinstance(shap_values, Explanation):
#      52     emsg = (
#      53         "The waterfall plot requires an `Explanation` object as the "
#      54         "`shap_values` argument."
#      55     )
# ---> 56     raise TypeError(emsg)
#      58 # make sure we only have a single explanation to plot
#      59 sv_shape = shap_values.shape
#
# TypeError: The waterfall plot requires an `Explanation` object as the `shap_values` argument.

# %%
shap.plots.scatter(shap_values[:,'boring',1], show = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 shap.plots.scatter(shap_values[:,'boring',1], show = True)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
shap.summary_plot(shap_values, X_test_vec_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 shap.summary_plot(shap_values, X_test_vec_df)
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\plots\_beeswarm.py:595, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale)
#     591 proj_shap_values = shap_values[:, sort_inds[0], sort_inds]
#     592 proj_shap_values[:, 1:] *= 2  # because off diag effects are split in half
#     593 summary_legacy(
#     594     proj_shap_values, features[:, sort_inds] if features is not None else None,
# --> 595     feature_names=feature_names[sort_inds],
#     596     sort=False, show=False, color_bar=False,
#     597     plot_size=None,
#     598     max_display=max_display
#     599 )
#     600 pl.xlim((slow, shigh))
#     601 pl.xlabel("")
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
import transformers
classifier = transformers.pipeline('sentiment-analysis', return_all_scores = True)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From C:\Users\xuanx\anaconda3\envs\springboard1\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# WARNING:tensorflow:From C:\Users\xuanx\anaconda3\envs\springboard1\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
print(train['reviews_fin'][:2])
# Out:
# index
# 1782    early access dlc enough said
# 3917             boring refunded zzz
# Name: reviews_fin, dtype: object

# %%
classifier([str(i) for i in train['reviews_fin'][:2].tolist()])
# Out:
# [[{'label': 'NEGATIVE', 'score': 0.28105252981185913},
#   {'label': 'POSITIVE', 'score': 0.7189474701881409}],
#  [{'label': 'NEGATIVE', 'score': 0.9994637370109558},
#   {'label': 'POSITIVE', 'score': 0.0005362608353607357}]]

# %%
explainer = shap.Explainer(classifier)

# %%
shap_values = explainer([str(i) for i in train['reviews_fin'][:2].tolist()])
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
# PartitionExplainer explainer:  50%|██████████████████████████████▌                              | 1/2 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
# PartitionExplainer explainer: 3it [00:25, 12.59s/it]

# %%
shap.plots.text(shap_values[:,:,'POSITIVE'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 shap.plots.text(shap_values[:,:,'POSITIVE'])
#
# File ~\anaconda3\envs\springboard1\Lib\site-packages\shap\_explanation.py:320, in Explanation.__getitem__(self, item)
#     318 if pos != 0 and pos in output_names_dims:
#     319     if len(output_names_dims) == 1:
# --> 320         t = np.argwhere(np.array(self.output_names) == t)[0][0]
#     321     elif len(output_names_dims) == 2:
#     322         new_values = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import copy

shap.initjs()
shap_values1 = copy.deepcopy(shap_values)
shap_values1.values = shap_values1.values[:,:,1]
shap_values1.base_values = shap_values1.base_values[:,1]

shap.plots.beeswarm(shap_values1, max_display = 20, show= False)
plt.savefig('beeswarm.png', bbox_inches="tight")

# %%
def f(X):
    return clf_fit.predict([X[:,i] for i in frange(X.shape[1])]).flatten()

# %%
explainer = shap.KernelExplainer(f, X.iloc[:50,:]), feature_names = words)
shap_values = explainer.shap_values(X.iloc[299,:], nsamples = 500)
shap.force_plot(explainer.expected_value, shap_values, X_display.iloc[299,:])

# %%
import copy

shap.initjs()
shap_values1 = copy.deepcopy(shap_values)
shap_values1.values = shap_values1.values[:,:,1]
shap_values1.base_values = shap_values1.base_values[:,1]

shap.plots.beeswarm(shap_values1, max_display = 20, show= False)
plt.savefig('beeswarm.png', bbox_inches="tight")

# %%
shap.initjs()

ind = 48
print(X_test.iloc[ind], y_test.iloc[ind])

# %%
shap.plots.waterfall(shap_values[ind,:,1], show = True)
plt.savefig('waterfall.png', bbox_inches="tight")

# %%
shap.plots.scatter(shap_values[:,words.tolist().index('story'),1], show = True)

plt.savefig('scatter.png', bbox_inches="tight")

# %%
y_test.value_counts()

# %%
feature_scores = pd.Series(clf_fit.feature_importances_,
                          index = words).sort_values(ascending=False)
feature_scores[:10]

# %%
from sklearn.metrics import precision_recall_curve

y_pred_proba = clf_fit.predict_proba(X_test_vec_df)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold = %f, F-Score = %.3f' % (thresholds[ix], fscore[ix]))
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(recall[ix], precision[ix], marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.savefig('prec_recall.png', bbox_inches="tight")
plt.show()
optimal_thresh = thresholds[ix]
optimal_prec = precision[ix]

# %%
feat_imp = feature_scores.nlargest(10).sort_values(ascending=True)
feat_imp.plot(kind = 'barh', figsize = (10,10))
plt.savefig('feat_imp.png', bbox_inches="tight")

# %%
from sklearn.metrics import confusion_matrix

y_pred = (y_pred_proba > optimal_thresh)
conf_mat = confusion_matrix(y_test, y_pred.astype(int), labels = [1,0])
conf_mat

# %%
print(X_test.shape)
y_pred_df = y_pred.astype(int)
X_variables = pd.DataFrame(X_test)
X_variables['predictions'] = y_pred_df

# %%
negative_reviews = X_variables[X_variables['predictions'] == 1 ]
negative_reviews.head(10)

# %%
negative_reviews.count()

# %%
X_variables.iloc[ind]

# %% [markdown]
# ## Unused Code For Now

# %%
import tensorflow.keras

shap.plots.scatter(shap_values[:,feature_names.index('story'),1], show = False)
plt.savefig('scatter.png', bbox_inches="tight")

# %%
explainer = shap.explainers.Permutation(clf_fit.predict_proba, shap.sample(X_train_vec_df, 100), max_evals = 3000
                                       )

# %%
nn_train_data = pd.concat([X_train, y_train], axis = 1)
nn_train_data.value_counts('recommended')

# %%
nn_balance = nn_train_data[nn_train_data['recommended']==0].sample(4198, random_state = 48)
nn_balance.value_counts('recommended')
nn_train = pd.concat([nn_balance, nn_train_data[nn_train_data['recommended']==1]])
nn_train.value_counts('recommended')
nn_xtrain = nn_train['reviews_fin']
nn_ytrain = nn_train['recommended']

# %%
vectorizer = TfidfVectorizer()
X_train_arr = vectorizer.fit_transform(nn_xtrain).toarray()

# %%
X_test_arr = vectorizer.transform(X_test).toarray()

# %%
print(X_train_arr.shape, X_test_arr.shape)

# %%
n_words = X_train_arr.shape[1]
n_words

# %%
nn_ytrain.value_counts()
y_test.value_counts()

# %%
#nn model
model = Sequential()
model.add(Dense(200, input_shape = (n_words,), activation = 'relu'))
#model.add(Dropout(0.1))
model.add(Dense(100, activation = 'relu'))
#model.add(Dropout(0.1))
model.add(Dense(1, activation ='sigmoid'))

tensorBoardCallback = TensorBoard(log_dir = './logs', write_graph = True)
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
start_time = datetime.datetime.now()

history = model.fit(X_train_arr, nn_ytrain, epochs = 10, callbacks=[tensorBoardCallback], verbose = 2,
                   validation_data = (X_test_arr, y_test))

# %%
loss, acc = model.evaluate(X_test_arr, y_test, verbose = 0)
print('Test Accuracy: %f' % (acc*100))

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(["Train", "test"], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(["Train", "test"], loc = 'upper right')
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# %%
precision.shape, recall.shape, thresholds.shape

# %%
precision = np.delete(precision, -1)
recall = np.delete(recall, -1)

precision.shape, recall.shape, thresholds.shape

# %%
#locate recall from selected precision

precision_score = optimal_prec
find_recall = interpolate.interp1d(precision, recall)
find_thresh = interpolate.interp1d(precision, thresholds)
thresh_value = find_thresh(precision_score)
recall_score = find_recall(precision_score)
recall_score, thresh_value

# %%
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(recall_score, precision_score, marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.show()

# %%
tpr_opt = find_tpr(thresh_value)
fpr_opt = find_fpr(thresh_value)
print(tpr_opt, fpr_opt, thresh_value)

# %%
#locating optimal point
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

find_tpr = interpolate.interp1d(thresholds, tpr) #plug in thresholds for tpr
find_fpr = interpolate.interp1d(thresholds, fpr) #plug in thresh for fpr
thresh_look = interpolate.interp1d(tpr, thresholds) #plug in tpr for thresholds

# %%
ttt = thresh_look(0.6) #threshold value for value of tpr
ttt

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
auc = roc_auc_score(y_test,y_pred_proba)
plt.plot([0,1],[0,1], linestyle ='--')
plt.plot(fpr, tpr, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(fpr_opt, tpr_opt, marker = 'o', color = 'black')
plt.title(label = 'ROC Curve Random Forest Classifier')
plt.show()

# %%
y_pred_opt = (y_pred_proba > ttt)
conf_mat_opt = confusion_matrix(y_test, y_pred_opt, labels = [0,1])
conf_mat_opt

# %%
#find best true negative (tn) results
tn = 7000
best_thresh = 0
for t in high_thresh:
    y_pred_opt = (y_pred_proba > t)
    conf_mat_opt = confusion_matrix(y_test, y_pred_opt, labels = [0,1])
    if conf_mat_opt[1][0] > tn:
        best_thresh = t
        tn = conf_mat_opt[1][0]
        conf_mat_best = conf_mat_opt

best_thresh, tn, conf_mat_best

# %%
high_thresh = thresholds[thresholds > 0.5]
high_thresh

# %%
from sklearn.metrics import accuracy_score

#accuracy prior to choosing threshold
accuracy = accuracy_score(y_test, y_pred_proba.astype('int'))
print(accuracy)

# %%
y_pred = y_pred_proba
y_pred = (y_pred >= opt_thresh).astype('int')

accuracy_thresh = accuracy_score(y_test, y_pred)
print(accuracy_thresh)

# %%
plt.plot(recall, precision, label = 'auc=%.3f' % auc, marker = '.')
plt.plot(0.9, prec_point, marker = 'o', color = 'black', label = 'Best')
plt.title(label = 'Precision Recall Curve')
plt.show()

# %%
#train = df_20_20.reset_index().groupby(['recommended']).apply(lambda x: x.sample(frac = 0.8, random_state = 42)
 #                                                            ).reset_index(drop = True).set_index('index')
train = df_20_20
#test = df_20_20.drop(train.index)

train['recommended'].value_counts()
test['recommended'].value_counts()
